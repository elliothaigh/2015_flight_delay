# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Import Data

# %% [markdown]
# /Users/elliothaigh/Desktop/Data Analytics Course/Airlines Project

# %%
# file path
path = r'/Users/elliothaigh/Desktop/Data Analytics Course/Airlines Project'

# %%
# import data sets
df_flights = pd.read_csv(os.path.join(path, '01 Data', 'flights.csv'), dtype={'DESTINATION_AIRPORT': str, 'ORIGIN_AIRPORT': str})
df_airports = pd.read_csv(os.path.join(path, '01 Data', 'airports.csv'))
df_airlines = pd.read_csv(os.path.join(path, '01 Data', 'airlines.csv'))

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### df_flights exploration

# %%
df_flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
df_flights.tail()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# ...

# %%
df_flights.shape
# Out:
# (5819079, 31)

# %%
df_flights.dtypes
# Out:
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# ...

# %%
df_flights.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %% [markdown]
# ### df_airports exploration

# %%
df_airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
df_airports.tail()
# Out:
#     IATA_CODE                              AIRPORT  \
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597

# %%
df_airports.shape
# Out:
# (322, 7)

# %%
df_airports.dtypes
# Out:
# IATA_CODE     object
# AIRPORT       object
# CITY          object
# STATE         object
# COUNTRY       object
# LATITUDE     float64
# LONGITUDE    float64
# dtype: object

# %%
df_airports.describe()
# Out:
#          LATITUDE   LONGITUDE
# count  319.000000  319.000000
# mean    38.981244  -98.378964
# std      8.616736   21.523492
# min     13.483450 -176.646030
# 25%     33.652040 -110.839385
# 50%     39.297610  -93.403070
# 75%     43.154675  -82.722995
# max     71.285450  -64.798560

# %% [markdown]
# ### df_airlines exploration

# %%
df_airlines.head()
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
df_airlines.tail()
# Out:
#    IATA_CODE                       AIRLINE
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
df_airlines.shape
# Out:
# (14, 2)

# %%
df_airlines.dtypes
# Out:
# IATA_CODE    object
# AIRLINE      object
# dtype: object

# %% [markdown]
# ## Wrangling

# %%
# Search for missing values
df_flights.isnull().sum()
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729195
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# AIRLINE_DELAY          4755640
# LATE_AIRCRAFT_DELAY    4755640
# ...

# %% [markdown]
# These values are null for a reason and therefore they do not need to be removed.

# %%
# Search for missing values
df_airports.isnull().sum()
# Out:
# IATA_CODE    0
# AIRPORT      0
# CITY         0
# STATE        0
# COUNTRY      0
# LATITUDE     3
# LONGITUDE    3
# dtype: int64

# %% [markdown]
# With only three airports missing longitudes and latitudes we can leave them as we still have the city and airport name.

# %%
# check for duplicates
df_dups = df_flights[df_flights.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH, DAY, DAY_OF_WEEK, AIRLINE, FLIGHT_NUMBER, TAIL_NUMBER, ORIGIN_AIRPORT, DESTINATION_AIRPORT, SCHEDULED_DEPARTURE, DEPARTURE_TIME, DEPARTURE_DELAY, TAXI_OUT, WHEELS_OFF, SCHEDULED_TIME, ELAPSED_TIME, AIR_TIME, DISTANCE, WHEELS_ON, TAXI_IN, SCHEDULED_ARRIVAL, ARRIVAL_TIME, ARRIVAL_DELAY, DIVERTED, CANCELLED, CANCELLATION_REASON, AIR_SYSTEM_DELAY, SECURITY_DELAY, AIRLINE_DELAY, LATE_AIRCRAFT_DELAY, WEATHER_DELAY]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# No duplicates found

# %% [markdown]
# ### Merging databases

# %%
# combine df_flights and df_airlines
merged_df = pd.merge(df_flights, df_airlines, left_on='AIRLINE', right_on = 'IATA_CODE')

# %%
merged_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4        AS             98      N407AS
# 1  2015      1    1            4        AS            135      N527AS
# 2  2015      1    1            4        AS            108      N309AS
# 3  2015      1    1            4        AS            122      N413AS
# 4  2015      1    1            4        AS            130      N457AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  DIVERTED  \
# 0            ANC                 SEA                    5  ...         0
# 1            SEA                 ANC                   25  ...         0
# 2            ANC                 SEA                   45  ...         0
# 3            ANC                 PDX                   50  ...         0
# 4            FAI                 SEA                  115  ...         0
#
#    CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# ...

# %%
# clean column names
merged_df = merged_df.drop(columns = ['AIRLINE_x', 'FLIGHT_NUMBER', 'TAIL_NUMBER', 'IATA_CODE'])

# %%
# combine df_airports with merged_df (origin airport)
merged_df2 = pd.merge(merged_df, df_airports, left_on='ORIGIN_AIRPORT', right_on='IATA_CODE', how='outer')

# %%
merged_df2.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0  2015      1    1            4            ANC                 SEA
# 1  2015      1    1            4            ANC                 SEA
# 2  2015      1    1            4            ANC                 PDX
# 3  2015      1    1            4            ANC                 SEA
# 4  2015      1    1            4            ANC                 SEA
#
#    SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  ...  \
# 0                    5          2354.0            -11.0      21.0  ...
# 1                   45            41.0             -4.0      17.0  ...
# 2                   50            46.0             -4.0      11.0  ...
# 3                  135             NaN              NaN       NaN  ...
# 4                  155           140.0            -15.0      17.0  ...
#
#    LATE_AIRCRAFT_DELAY  WEATHER_DELAY             AIRLINE_y  IATA_CODE  \
# ...

# %%
# combine df_airports with merged_df (destination airport)
merged_df2 = pd.merge(merged_df2, df_airports, left_on='DESTINATION_AIRPORT', right_on='IATA_CODE', how='outer')

# %%
merged_df2.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0  2015      1    1            4            ANC                 SEA
# 1  2015      1    1            4            ANC                 SEA
# 2  2015      1    1            4            ANC                 SEA
# 3  2015      1    1            4            ANC                 SEA
# 4  2015      1    1            4            ANC                 SEA
#
#    SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  \
# 0                    5          2354.0            -11.0      21.0        15.0
# 1                   45            41.0             -4.0      17.0        58.0
# 2                  135             NaN              NaN       NaN         NaN
# 3                  155           140.0            -15.0      17.0       157.0
# 4                  220           209.0            -11.0      15.0       224.0
#
#    SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# ...

# %% [markdown]
# ### Drop columns

# %%
# Check columns
for col in merged_df2:
    print(col)
# Out:
# YEAR
# MONTH
# DAY
# DAY_OF_WEEK
# ORIGIN_AIRPORT
# DESTINATION_AIRPORT
# SCHEDULED_DEPARTURE
# DEPARTURE_TIME
# DEPARTURE_DELAY
# TAXI_OUT
# WHEELS_OFF
# SCHEDULED_TIME
# ELAPSED_TIME
# AIR_TIME
# DISTANCE
# WHEELS_ON
# TAXI_IN
# SCHEDULED_ARRIVAL
# ARRIVAL_TIME
# ARRIVAL_DELAY
# DIVERTED
# CANCELLED
# CANCELLATION_REASON
# AIR_SYSTEM_DELAY
# SECURITY_DELAY
# AIRLINE_DELAY
# LATE_AIRCRAFT_DELAY
# WEATHER_DELAY
# AIRLINE_y
# IATA_CODE_x
# AIRPORT_x
# CITY_x
# STATE_x
# COUNTRY_x
# LATITUDE_x
# LONGITUDE_x
# IATA_CODE_y
# AIRPORT_y
# CITY_y
# STATE_y
# COUNTRY_y
# LATITUDE_y
# LONGITUDE_y

# %%
# We do not need some columns for our analysis and therefore will remove them from the dataframe
merged_df2 = merged_df2.drop(columns = ['ORIGIN_AIRPORT', 'DESTINATION_AIRPORT'])

# %% [markdown]
# ### Renming Columns

# %%
dict = {'AIRLINE_y' : 'AIRLINE',
        'IATA_CODE_x':'ORIGIN_AIRPORT_CODE',
        'AIRPORT_x':'ORIGIN_AIRPORT',
        'CITY_x':'ORIGIN_CITY',
        'STATE_x' : 'ORIGIN_STATE',
        'COUNTRY_x': 'ORIGIN_COUNTRY',
        'LATITUDE_x': 'ORIGIN_LATITUDE',
        'LONGITUDE_x': 'ORIGIN_LONGITUDE',
       'IATA_CODE_y':'DESTINATION_AIRPORT_CODE',
        'AIRPORT_y':'DESTINATION_AIRPORT',
        'CITY_y':'DESTINATION_CITY',
        'STATE_y' : 'DESTINATION_STATE',
        'COUNTRY_y': 'DESTINATION_COUNTRY',
        'LATITUDE_y': 'DESTINATION_LATITUDE',
        'LONGITUDE_y': 'DESTINATION_LONGITUDE'}

# %%
merged_df2.rename(columns=dict,
          inplace=True)

# %%
# Check column names
for col in merged_df2:
    print(col)
# Out:
# YEAR
# MONTH
# DAY
# DAY_OF_WEEK
# SCHEDULED_DEPARTURE
# DEPARTURE_TIME
# DEPARTURE_DELAY
# TAXI_OUT
# WHEELS_OFF
# SCHEDULED_TIME
# ELAPSED_TIME
# AIR_TIME
# DISTANCE
# WHEELS_ON
# TAXI_IN
# SCHEDULED_ARRIVAL
# ARRIVAL_TIME
# ARRIVAL_DELAY
# DIVERTED
# CANCELLED
# CANCELLATION_REASON
# AIR_SYSTEM_DELAY
# SECURITY_DELAY
# AIRLINE_DELAY
# LATE_AIRCRAFT_DELAY
# WEATHER_DELAY
# AIRLINE
# ORIGIN_AIRPORT_CODE
# ORIGIN_AIRPORT
# ORIGIN_CITY
# ORIGIN_STATE
# ORIGIN_COUNTRY
# ORIGIN_LATITUDE
# ORIGIN_LONGITUDE
# DESTINATION_AIRPORT_CODE
# DESTINATION_AIRPORT
# DESTINATION_CITY
# DESTINATION_STATE
# DESTINATION_COUNTRY
# DESTINATION_LATITUDE
# DESTINATION_LONGITUDE

# %%
df_merged =merged_df.rename(columns = {'AIRLINE_y' : 'AIRLINE'})

# %%
# Check column names
for col in df_merged:
    print(col)
# Out:
# YEAR
# MONTH
# DAY
# DAY_OF_WEEK
# SCHEDULED_DEPARTURE
# DEPARTURE_TIME
# DEPARTURE_DELAY
# TAXI_OUT
# WHEELS_OFF
# SCHEDULED_TIME
# ELAPSED_TIME
# AIR_TIME
# DISTANCE
# WHEELS_ON
# TAXI_IN
# SCHEDULED_ARRIVAL
# ARRIVAL_TIME
# ARRIVAL_DELAY
# DIVERTED
# CANCELLED
# CANCELLATION_REASON
# AIR_SYSTEM_DELAY
# SECURITY_DELAY
# AIRLINE_DELAY
# LATE_AIRCRAFT_DELAY
# WEATHER_DELAY
# AIRLINE
# ORIGIN_AIRPORT_CODE
# ORIGIN_AIRPORT
# ORIGIN_CITY
# ORIGIN_STATE
# ORIGIN_COUNTRY
# ORIGIN_LATITUDE
# ORIGIN_LONGITUDE
# DESTINATION_AIRPORT_CODE
# DESTINATION_AIRPORT
# DESTINATION_CITY
# DESTINATION_STATE
# DESTINATION_COUNTRY
# DESTINATION_LATITUDE
# DESTINATION_LONGITUDE

# %%
# Check data types
df_merged.dtypes
# Out:
# YEAR                          int64
# MONTH                         int64
# DAY                           int64
# DAY_OF_WEEK                   int64
# SCHEDULED_DEPARTURE           int64
# DEPARTURE_TIME              float64
# DEPARTURE_DELAY             float64
# TAXI_OUT                    float64
# WHEELS_OFF                  float64
# SCHEDULED_TIME              float64
# ELAPSED_TIME                float64
# AIR_TIME                    float64
# DISTANCE                      int64
# WHEELS_ON                   float64
# TAXI_IN                     float64
# SCHEDULED_ARRIVAL             int64
# ARRIVAL_TIME                float64
# ARRIVAL_DELAY               float64
# DIVERTED                      int64
# CANCELLED                     int64
# CANCELLATION_REASON          object
# AIR_SYSTEM_DELAY            float64
# SECURITY_DELAY              float64
# AIRLINE_DELAY               float64
# LATE_AIRCRAFT_DELAY         float64
# WEATHER_DELAY               float64
# ...

# %% [markdown]
# ### Export database

# %%
df_merged.to_pickle(os.path.join(path, '01 Data', 'flights_merged.pkl'))
